# %% [markdown]
# # Review by M2 - Data Preparation
#
# **Name:** Yuxuan Wang
#
# ## Team structure and role allocation
#
# At first the assessment brief say team roles should follow alphabetical order. But we agree to choose roles based on what people felt more comfortable doing.
#
# Roles:
#
# - M1 – Abdulaziz Alsulami
# - M2 – Yuxuan Wang
# - M3 – Sarah Dughrush
# - M4 – Justin Chu Jing Hang

# %% [markdown]
# # 1. Introduction
#
# My role in this project was Team Member 2 (M2). My task was mainly related to preparing and organising the answer files before later stages of analysis.
#
# During the project I also receive many guidance and support from Justin Chu Jing Hang (M4) because I was not very familiar with GitHub workflow and some coding parts. He helped explain many things and also helped me understand how different parts connect together.
#
# This review explains my work, testing process and what I learned during project.

# %% [markdown]
# # 2. My contribution
#
# My part mainly focused on preparing and organising data files so they can be used by later modules.
#
# Tasks completed:
#
# - Worked on M2 preparation module
# - Helped process and organise respondent files
# - Made sure files can be prepared into a usable format
# - Tested whether generated outputs could continue into later modules
# - Fixed some issues during preparation process
# - Used GitHub branches and commits during project work
# - Discussed problems with team members
# - Received a lot of guidance from Justin during implementation and debugging
#
# Justin helped me many times during coding because sometimes I was not sure how GitHub workflow and integration should be done. This support helped me continue my part and understand project better.

# %% [markdown]
# # 3. Testing and checking
#
# To check whether my work was functioning correctly, I tested if the preparation stage can run correctly and produce expected outputs.
#
# Things checked:
#
# - Tested if preparation module can run without errors
# - Checked output files were created correctly
# - Made sure generated files can be used by later modules
# - Checked folder paths and file names
# - Discussed problems with teammates when issues happened
#
# During testing some problems happened and needed debugging. Sometimes there were issues with file structure and integration between modules. Justin also helped a lot during this process because I was still learning how everything connects together.
#
# After fixing issues, the preparation stage worked properly and could continue into later project stages.

# %% [markdown]
# # 4. Evidence and interpretation
#
# I included screenshots of outputs and project files as evidence.
#
# From the results I think preparation stage worked correctly because files were generated and later modules could continue running. This means the output format was accepted by other parts of project.
#
# I also learned that testing is important because sometimes code can run by itself but still have issues when connecting with other modules.
#
# This also showed me that teamwork and discussion was important because different members worked on different parts and we needed help from each other.

# %% [markdown]
# # 5. Reflection
#
# From this project I learned more about GitHub, commits and working in a shared repository. Before this project I was not very confident with GitHub workflow.
#
# I also learned that group project is not only writing code. Communication and helping each other is also important.
#
# I received a lot of support and guidance from Justin during project, especially for GitHub workflow and debugging problems. Through this I understood project structure better and learned many things that I did not know before.
#
# Overall I think this project helped improve my technical skills and teamwork experience.
