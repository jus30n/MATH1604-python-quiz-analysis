# %% [markdown]
# # M3 Module Review by Team Member 3 - Analysis & Visualization
# **Module name:** `data_analysis_M3.py`
#
# ## 1. Introduction
# The core task of the M3 module includes analysing the data for quizzes collected together and making visualizations to look for any patterns hidden in this data. The M3 module depends largely on the output file produced by the M2 module – collated_answers.txt file and the extraction algorithm made by the M1 module.

# %% [markdown]
# ## 2. Data Processing and Means Calculation
# The central calculations are carried out within the function named `generate_means_sequence`. Due to the fact that M1’s extraction algorithm was programmed to work with one document at a time, I came up with another function to extract M2’s huge concatenated document and separate its components with the help of asterisks (`*`).
#
# After parsing the information with M1’s function, I computed the mean answer to each of the 100 questions. One of the conditions set by the assignment was the ability to deal with unanswered questions. The program developed by M1 gives zeros for such instances. Hence, the algorithm used in my calculations ignores zeros.

# %%
## 3. Visualization and Analysis Results
The function called `visualize_data` produces two distinct types of visualization according to the input argument specified:
* **Input argument n=1:** Produces a scatter graph representing the mean average values for each of the 100 questions.
* **Input argument n=2:** Produces a line graph showing all 64 respondents' answering sequences in one line.

**Hidden Sequence Revealed:**
In the course of creating visualizations for the final dataset, it becomes strikingly evident that there is an explicit pattern visible in the latter part of the quiz. From around question number 60, there appears a strict alternating cycle of the sequence `4, 3, 2, 1, 1, 2, 3, 4` without any randomness.

Since in a randomizing process there cannot emerge such a perfectly ordered countdown, and since the quiz has been made deliberately by a quizsetter, the visualizations prove to be highly successful in detecting the hidden mirroring sequence.
